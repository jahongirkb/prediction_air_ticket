# %% [markdown]
# # LIBRARIES NEEDED IN THE STUDY

# %%
import pandas as pd
import numpy as np
import sklearn # scikit-learn library

# Scaling
from sklearn.preprocessing import scale 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder 
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import mean_squared_error

from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Reading the Data

# %%
URL = "https://github.com/jahongirkb/prediction_air_ticket/blob/main/train_data.csv?raw=true"
df = pd.read_csv(URL)
df.head()
# Out:
#    id   airline   flight source_city departure_time stops arrival_time  \
# 0   1   Vistara   UK-810   Bangalore  Early_Morning   one        Night
# 1   2  SpiceJet  SG-5094   Hyderabad        Evening  zero        Night
# 2   3   Vistara   UK-846   Bangalore        Morning   one      Evening
# 3   4   Vistara   UK-706     Kolkata        Morning   one      Evening
# 4   5    Indigo  6E-5394     Chennai  Early_Morning  zero      Morning
#
#   destination_city     class  duration  days_left  price
# 0           Mumbai   Economy     14.25         21   7212
# 1          Kolkata   Economy      1.75          7   5292
# 2            Delhi  Business      9.58          5  60553
# 3        Hyderabad   Economy      6.75         28   5760
# 4           Mumbai   Economy      2.00          4  10712

# %% [markdown]
# # Dividing train test split

# %%
train_set, test_set = train_test_split(df, test_size=0.2, random_state=10)

X_train = train_set.drop(["price", 'flight', 'id'], axis=1)
y = train_set["price"].copy()

X_num = X_train[["duration", 'days_left']]

# %% [markdown]
# # Make pipeline

# %% [markdown]
# for numeric

# %%
num_pipeline = Pipeline([
          ('std_scaler', StandardScaler())             
])

# %% [markdown]
# for categorical

# %%
num_attribs = ["duration", 'days_left']
cat_attribs = ['airline', 'source_city', 'departure_time', 'stops', 'arrival_time', 'destination_city', 'class']

full_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_attribs),
    ('cat', OneHotEncoder(), cat_attribs)
])

# %%
X_prepared = full_pipeline.fit_transform(X_train)

# %%
X_prepared
# Out:
# <16000x37 sparse matrix of type '<class 'numpy.float64'>'
# 	with 144000 stored elements in Compressed Sparse Row format>

# %%
from sklearn.ensemble import RandomForestRegressor
RF_model = RandomForestRegressor()
RF_model.fit(X_prepared, y)
# Out:
# RandomForestRegressor()

# %%
test_data = X_train.sample(5)
test_data
# Out:
#          airline source_city departure_time stops arrival_time  \
# 5135     Vistara      Mumbai        Morning   one    Afternoon
# 5890    SpiceJet     Kolkata          Night   one      Morning
# 7634     Vistara     Kolkata        Morning   one    Afternoon
# 11640     Indigo     Kolkata        Evening   one   Late_Night
# 747    Air_India       Delhi  Early_Morning   one   Late_Night
#
#       destination_city     class  duration  days_left
# 5135             Delhi   Economy      5.08         10
# 5890            Mumbai   Economy     10.67         29
# 7634         Hyderabad  Business     25.83         26
# 11640        Hyderabad   Economy      7.92         38
# 747          Bangalore   Economy     19.00         10

# %%
test_label = y.loc[test_data.index]
test_label
# Out:
# 5135     12138
# 5890      6276
# 7634     49207
# 11640     8380
# 747      11520
# Name: price, dtype: int64

# %%
test_data_prepared = full_pipeline.transform(test_data)
test_data_prepared
# Out:
# <5x37 sparse matrix of type '<class 'numpy.float64'>'
# 	with 45 stored elements in Compressed Sparse Row format>

# %%
predicted_data = RF_model.predict(test_data_prepared)
predicted_data
# Out:
# array([12298.08,  5963.27, 49628.47,  7474.72, 12119.48])

# %%
pd.DataFrame({'Prediction':predicted_data, 'Real value': test_label})
# Out:
#        Prediction  Real value
# 5135     12298.08       12138
# 5890      5963.27        6276
# 7634     49628.47       49207
# 11640     7474.72        8380
# 747      12119.48       11520

# %%
test_set
# Out:
#           id    airline   flight source_city departure_time        stops  \
# 19778  19779   GO_FIRST   G8-103       Delhi        Evening         zero
# 4376    4377     Indigo  6E-2005       Delhi        Morning         zero
# 10188  10189    AirAsia   I5-721       Delhi          Night          one
# 9887    9888    Vistara   UK-809       Delhi        Evening          one
# 4441    4442    AirAsia   I5-517     Chennai        Morning         zero
# ...      ...        ...      ...         ...            ...          ...
# 13123  13124    Vistara   UK-910      Mumbai        Evening          one
# 18706  18707     Indigo  6E-5398      Mumbai        Morning          one
# 7274    7275    AirAsia   I5-550       Delhi        Evening          one
# 16155  16156     Indigo  6E-2247       Delhi        Morning          one
# 16712  16713  Air_India   AI-429     Chennai      Afternoon  two_or_more
#
#         arrival_time destination_city     class  duration  days_left  price
# 19778          Night          Kolkata   Economy      2.33          5   5954
# 4376         Morning        Hyderabad   Economy      2.25         42   3013
# 10188        Morning        Hyderabad   Economy     12.00         21   2050
# 9887         Morning        Hyderabad   Economy     13.25         34   5761
# 4441         Morning        Hyderabad   Economy      1.17          7   4203
# ...              ...              ...       ...       ...        ...    ...
# 13123          Night        Hyderabad  Business      5.33         21  61597
# 18706        Evening          Chennai   Economy      8.00          7  10731
# 7274   Early_Morning        Hyderabad   Economy     13.92         18   2050
# 16155          Night        Bangalore   Economy      9.75         31   4007
# 16712        Evening        Bangalore   Economy     29.17          4  13128
#
# [4000 rows x 12 columns]

# %%
X_test = test_set.drop(['price', 'flight', 'id'], axis=1)
X_test
# Out:
#          airline source_city departure_time        stops   arrival_time  \
# 19778   GO_FIRST       Delhi        Evening         zero          Night
# 4376      Indigo       Delhi        Morning         zero        Morning
# 10188    AirAsia       Delhi          Night          one        Morning
# 9887     Vistara       Delhi        Evening          one        Morning
# 4441     AirAsia     Chennai        Morning         zero        Morning
# ...          ...         ...            ...          ...            ...
# 13123    Vistara      Mumbai        Evening          one          Night
# 18706     Indigo      Mumbai        Morning          one        Evening
# 7274     AirAsia       Delhi        Evening          one  Early_Morning
# 16155     Indigo       Delhi        Morning          one          Night
# 16712  Air_India     Chennai      Afternoon  two_or_more        Evening
#
#       destination_city     class  duration  days_left
# 19778          Kolkata   Economy      2.33          5
# 4376         Hyderabad   Economy      2.25         42
# 10188        Hyderabad   Economy     12.00         21
# 9887         Hyderabad   Economy     13.25         34
# 4441         Hyderabad   Economy      1.17          7
# ...                ...       ...       ...        ...
# 13123        Hyderabad  Business      5.33         21
# 18706          Chennai   Economy      8.00          7
# 7274         Hyderabad   Economy     13.92         18
# 16155        Bangalore   Economy      9.75         31
# 16712        Bangalore   Economy     29.17          4
#
# [4000 rows x 9 columns]

# %%
y_test = test_set['price'].copy()
y_test
# Out:
# 19778     5954
# 4376      3013
# 10188     2050
# 9887      5761
# 4441      4203
#          ...
# 13123    61597
# 18706    10731
# 7274      2050
# 16155     4007
# 16712    13128
# Name: price, Length: 4000, dtype: int64

# %%
X_test_prepared = full_pipeline.transform(X_test)

# %%
y_predicted = RF_model.predict(X_test_prepared)

# %%
lin_mse = mean_squared_error(y_test, y_predicted)
# RMSE hisoblaymiz
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)
# Out:
# 3883.246810739448

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Std.dev:", scores.std())

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(RF_model, X_prepared, y, scoring="neg_mean_squared_error", cv=10)
LR_rmse_scores = np.sqrt(-scores)

# %%
display_scores(LR_rmse_scores)
# Out:
# Scores: [4087.75541674 4056.55720348 3864.40239232 4126.88271586 3615.7160062
#  3711.52349633 3711.75751257 3836.18360743 3730.17248205 4081.5088202 ]
# Mean: 3882.2459653175597
# Std.dev: 180.82824411493993

# %%
URL = "https://github.com/jahongirkb/prediction_air_ticket/blob/main/test_data.csv?raw=true"
df_test = pd.read_csv(URL)
df_test.head()
# Out:
#    id    airline  flight source_city departure_time stops   arrival_time  \
# 0   1  Air_India  AI-765     Kolkata        Evening   one          Night
# 1   2    Vistara  UK-747       Delhi  Early_Morning   one          Night
# 2   3  Air_India  AI-570      Mumbai  Early_Morning  zero  Early_Morning
# 3   4    AirAsia  I5-974   Hyderabad          Night   one     Late_Night
# 4   5  Air_India  AI-770     Kolkata          Night   one      Afternoon
#
#   destination_city     class  duration  days_left
# 0            Delhi  Business     28.25          2
# 1           Mumbai  Business     13.83         34
# 2          Chennai  Business      2.00         30
# 3            Delhi   Economy      5.17         26
# 4           Mumbai   Economy     16.33         35

# %%
df_test.shape
# Out:
# (5000, 11)

# %%
df_test = df_test.drop(['flight', 'id'],  axis=1)

# %%
df_test_prepared = full_pipeline.transform(df_test)

# %%
df_predicted = RF_model.predict(df_test_prepared)

# %%
df_predicted
# Out:
# array([52854.79, 58032.77, 23352.5 , ..., 50281.58, 47340.83, 62935.17])

# %%
df_predicted.shape
# Out:
# (5000,)

# %%
URL = "https://github.com/jahongirkb/prediction_air_ticket/blob/main/sample_solution.csv?raw=true"
df_sample = pd.read_csv(URL)
df_sample.head()
# Out:
#    id  price
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0

# %%
df_sample.shape
# Out:
# (5000, 2)

# %%
df_sample['price'] = df_predicted

# %%
df_sample.head()
# Out:
#    id     price
# 0   1  52854.79
# 1   2  58032.77
# 2   3  23352.50
# 3   4   2684.11
# 4   5   5619.72

# %%
df_sample.to_csv("my_submission.csv", index=False)

# %%
URL = "/content/my_submission.csv"
df_sub = pd.read_csv(URL)
df_sub.head()
# Out:
#    id     price
# 0   1  52854.79
# 1   2  58032.77
# 2   3  23352.50
# 3   4   2684.11
# 4   5   5619.72
